# %% [markdown]
# # RAMP: Unveiling Energy Landscapes: Exploring Energy Performance Diagnosis (DPE) in Paris Before July 2021
# *AGUDELO Julian, BAROUDI Malek,KASSARA Nada, PONCE Afonso, ROUSSEAU Paul, VERLYNDE Matthieu*
# <div>
#     <table style="width:100%; background-color:transparent;">
#         <tr style="background-color:transparent;">
#             <td align="left" style="background-color:transparent; width: 40%;">
#                 <a href="https://www.agroparistech.fr/">
#                     <img src="https://www.aptalumni.org/images/news/apt-logo-sloganfranc-ais-rvb-positif-002.png" alt="Texte alternatif" width="450px" />
#                 </a>
#             </td>
#             <td align="right" style="background-color:transparent; width: 40%;">
#                 <a href="https://www.geops.universite-paris-saclay.fr/">
#                     <img src="https://i.pinimg.com/originals/4c/60/61/4c6061817fe38c9cf17cd55c4f9e1a55.png" alt="Texte alternatif" width="450px" />
#                 </a>
#             </td>
#         </tr>
#     </table>
# </div>
#
#
#
# ## Table of Contents
# * [Introduction](#introduction)
# * [The dataset](#dataset)
# * [Data exploration](#exploration)
# * [Requirements](#requirements)
# * [Base model](#base_model)
# * [Submitting on RAMP](#submitting)

# %% [markdown]
# ## Introduction to the Energy Performance Diagnosis (DPE) - Paris (Before July 2021)<a class="anchor" id="introduction"></a>
#
# The Energy Performance Diagnosis (DPE) serves as a comprehensive tool for assessing the energy performance of residences and buildings, providing insights into their energy consumption and environmental impact in terms of greenhouse gas emissions.
#
# The establishment of DPE is subject to regulated content and procedures. This diagnostic meticulously outlines the characteristics of the building or dwelling, encompassing details such as surface area, orientation, walls, windows, materials, and more. Additionally, it encompasses an evaluation of heating systems, hot water production, cooling, and ventilation equipment. Depending on the scenario, the DPE indicates either the actual energy consumption based on invoices or the estimated energy consumption for standardized usage of the building or dwelling.
#
# Facilitating the interpretation of DPE information are two labels, each classified into seven classes ranging from A to G, where A represents the highest performance and G the lowest:
#
# 1. **Energy Label:** Provides insights into primary energy consumption.
# 2. **Climate Label:** Reveals the quantity of greenhouse gases emitted.
#
# Crucially, the Diagnostic de Performance Énergétique must be conducted by an independent professional meeting specific competency criteria and holding adequate insurance. This regulatory framework ensures the reliability and accuracy of the assessment.
#
# By delving into the DPE of residences in Paris, specifically before July 2021, we gain a nuanced understanding of the energy landscape in this dynamic urban environment. This introduction sets the stage for exploring the implications and applications of DPE data in enhancing energy efficiency and sustainability practices within the context of the vibrant city of Paris.

# %% [markdown]
# ## The dataset <a class="anchor" id="dataset"></a>

# %% [markdown]
# Intro rapide
# preprocessing : Expliquer qu'on a supprimé les colonnes ci-dessous + qu'on a remplacé la colonne de classes (A, B, C, D..) en chiffres + modification des types pour certaines colonnes
#
# 300 000 lignes

# %% [markdown]
# ['id', 'numero_dpe', 'version_methode_dpe',
#        'nom_methode_etude_thermique', 'version_methode_etude_thermique',
#        'commentaires_ameliorations_recommandations',
#        'explication_personnalisee', 'estimation_ges',
#        'classe_estimation_ges', 'nom_rue', 'numero_rue',
#        'batiment', 'escalier', 'etage', 'porte', 'numero_lot',
#        'partie_batiment', 'adresse_organisme_certificateur']

# %% [markdown]
# ## Requirements <a class="anchor" id="requirements"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.exceptions import FitFailedWarning
import missingno as msno
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# Out:
# /tmp/ipykernel_4618/1178242339.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Download Data

# %%
# Uncomment the following line to download data:
#!python download_data.py

# %% [markdown]
# ## Data Exploration <a class="anchor" id="exploration"></a>

# %% [markdown]
# ### Data

# %%
train = pd.read_csv('data/public/train.csv')
test = pd.read_csv('data/public/test.csv')
# put train and test together
df = pd.concat([train, test])
# Out:
# /tmp/ipykernel_4618/2960635763.py:1: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('data/public/train.csv')
# /tmp/ipykernel_4618/2960635763.py:2: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   test = pd.read_csv('data/public/test.csv')

# %%
# Missingness
msno.matrix(df)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89445 entries, 0 to 26833
# Data columns (total 67 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              89445 non-null  int64
#  1   numero_dpe                                      89445 non-null  object
#  2   usr_diagnostiqueur_id                           89445 non-null  int64
#  3   usr_logiciel_id                                 89445 non-null  int64
#  4   tr001_modele_dpe_id                             89445 non-null  int64
#  5   nom_methode_dpe                                 89445 non-null  object
#  6   version_methode_dpe                             55359 non-null  object
#  7   nom_methode_etude_thermique                     4087 non-null   object
#  8   version_methode_etude_thermique                 3703 non-null   object
#  9   date_visite_diagnostiqueur                      89445 non-null  object
#  10  date_etablissement_dpe                          89445 non-null  object
#  11  date_arrete_tarifs_energies                     89445 non-null  object
#  12  commentaires_ameliorations_recommandations      17118 non-null  object
#  13  explication_personnalisee                       10759 non-null  object
#  14  consommation_energie                            89445 non-null  float64
#  15  classe_consommation_energie                     89445 non-null  object
#  16  estimation_ges                                  89445 non-null  float64
#  17  classe_estimation_ges                           89445 non-null  object
#  18  tr002_type_batiment_id                          89445 non-null  int64
#  19  secteur_activite                                16369 non-null  object
#  20  tr012_categorie_erp_id                          2050 non-null   float64
#  21  tr013_type_erp_id                               7774 non-null   float64
#  22  annee_construction                              89445 non-null  int64
#  23  surface_habitable                               88728 non-null  float64
#  24  surface_thermique_lot                           88728 non-null  float64
#  25  tv016_departement_id                            89445 non-null  int64
#  26  commune                                         88930 non-null  object
#  27  arrondissement                                  34498 non-null  object
#  28  type_voie                                       27949 non-null  object
#  29  nom_rue                                         89252 non-null  object
#  30  numero_rue                                      28501 non-null  object
#  31  batiment                                        5006 non-null   object
#  32  escalier                                        31080 non-null  object
#  33  etage                                           12653 non-null  object
#  34  porte                                           8298 non-null   object
#  35  code_postal                                     88912 non-null  object
#  36  code_insee_commune                              88911 non-null  object
#  37  code_insee_commune_actualise                    88911 non-null  object
#  38  numero_lot                                      52090 non-null  object
#  39  surface_commerciale_contractuelle               11328 non-null  object
#  40  portee_dpe_batiment                             71950 non-null  float64
#  41  partie_batiment                                 2453 non-null   object
#  42  shon                                            69739 non-null  float64
#  43  surface_utile                                   72061 non-null  float64
#  44  surface_thermique_parties_communes              71950 non-null  float64
#  45  en_souterrain                                   69738 non-null  float64
#  46  en_surface                                      69738 non-null  float64
#  47  nombre_niveaux                                  71950 non-null  float64
#  48  nombre_circulations_verticales                  69738 non-null  float64
#  49  nombre_boutiques                                69738 non-null  float64
#  50  presence_verriere                               71950 non-null  float64
#  51  surface_verriere                                69738 non-null  float64
#  52  type_vitrage_verriere                           0 non-null      float64
#  53  nombre_entrees_avec_sas                         69738 non-null  float64
#  54  nombre_entrees_sans_sas                         69740 non-null  float64
#  55  surface_baies_orientees_nord                    69850 non-null  float64
#  56  surface_baies_orientees_est_ouest               69850 non-null  float64
#  57  surface_baies_orientees_sud                     69850 non-null  float64
#  58  surface_planchers_hauts_deperditifs             69850 non-null  float64
#  59  surface_planchers_bas_deperditifs               69850 non-null  float64
#  60  surface_parois_verticales_opaques_deperditives  69850 non-null  float64
#  61  etat_avancement                                 89445 non-null  int64
#  62  organisme_certificateur                         88584 non-null  object
#  63  adresse_organisme_certificateur                 86021 non-null  object
#  64  dpe_vierge                                      84462 non-null  float64
#  65  est_efface                                      89445 non-null  int64
#  66  date_reception_dpe                              89445 non-null  object
# dtypes: float64(27), int64(9), object(31)
# memory usage: 46.4+ MB

# %%
print(df.isnull().sum())
# Out:
# id                                    0
# numero_dpe                            0
# usr_diagnostiqueur_id                 0
# usr_logiciel_id                       0
# tr001_modele_dpe_id                   0
#                                    ...
# organisme_certificateur             861
# adresse_organisme_certificateur    3424
# dpe_vierge                         4983
# est_efface                            0
# date_reception_dpe                    0
# Length: 67, dtype: int64

# %%
missing_values_by_row = df.isnull().sum(axis=1)
missing_values_by_row
# Out:
# 0        18
# 1        17
# 2        19
# 3        35
# 4        17
#          ..
# 26829    17
# 26830    20
# 26831    18
# 26832    16
# 26833    36
# Length: 89445, dtype: int64

# %% [markdown]
# ## Labels
# The target variable is in the column classe_consommation_energie since we classify energy performance.

# %%
df.classe_consommation_energie.unique().shape, df.classe_consommation_energie.unique()
# Out:
# ((8,), array(['E', 'D', 'N', 'A', 'B', 'C', 'F', 'G'], dtype=object))

# %% [markdown]
# There are 9 events to classify examples from.

# %%
sns.countplot(x='classe_consommation_energie',hue='classe_consommation_energie',data = df)
# change the axes names
plt.xlabel('Classe Consommation Energie')
plt.ylabel('Count')
df['classe_consommation_energie'].value_counts()
# Out:
# classe_consommation_energie
# N    27788
# D    17815
# E    16698
# F     7720
# C     6767
# A     4256
# B     4241
# G     4160
# Name: count, dtype: int64

# %% [markdown]
# You can see that we deal with an imbalanced dataset, where some classes have  almost 4 times more observations than others.

# %%
df.describe()
# Out:
#                  id  usr_diagnostiqueur_id  usr_logiciel_id  \
# count  8.944500e+04           89445.000000     89445.000000
# mean   4.221079e+06            9976.931198         5.770071
# std    2.672225e+06            5364.080980         3.852795
# min    1.760000e+02               6.000000         2.000000
# 25%    1.880865e+06            5675.000000         3.000000
# 50%    4.071083e+06           10003.000000         3.000000
# 75%    6.372015e+06           14248.000000        10.000000
# max    9.431400e+06           22627.000000        16.000000
#
#        tr001_modele_dpe_id  consommation_energie  estimation_ges  \
# count         89445.000000          8.944500e+04    89445.000000
# mean              5.609738          2.433373e+02       35.171220
# std               4.422236          1.195494e+04     2751.099069
# min               1.000000          0.000000e+00        0.000000
# 25%               2.000000          0.000000e+00        0.000000
# 50%               2.000000          1.638900e+02       11.910000
# 75%              10.000000          2.700000e+02       36.190000
# max              24.000000          3.110395e+06   727825.460000
#
#        tr002_type_batiment_id  tr012_categorie_erp_id  tr013_type_erp_id  \
# count            89445.000000             2050.000000        7774.000000
# mean                 2.225323                2.675610          18.774891
# std                  0.657327                1.881984           7.665881
# min                  1.000000                1.000000           1.000000
# 25%                  2.000000                1.000000          12.000000
# 50%                  2.000000                1.000000          23.000000
# 75%                  2.000000                5.000000          23.000000
# max                  5.000000                5.000000          30.000000
#
#        annee_construction  ...  nombre_entrees_sans_sas  \
# count        89445.000000  ...             69740.000000
# mean          1903.510012  ...                 0.000029
# std            340.558367  ...                 0.007573
# min              0.000000  ...                 0.000000
# 25%           1947.000000  ...                 0.000000
# 50%           1947.000000  ...                 0.000000
# 75%           1970.000000  ...                 0.000000
# max          32767.000000  ...                 2.000000
#
#        surface_baies_orientees_nord  surface_baies_orientees_est_ouest  \
# count                  69850.000000                       69850.000000
# mean                       1.426815                           2.348840
# std                       17.299551                          38.963261
# min                        0.000000                           0.000000
# 25%                        0.000000                           0.000000
# 50%                        0.000000                           0.000000
# 75%                        0.000000                           0.000000
# max                     1782.640000                        4510.660000
#
#        surface_baies_orientees_sud  surface_planchers_hauts_deperditifs  \
# count                 69850.000000                         69850.000000
# mean                      1.568640                            12.647845
# std                      24.199622                            70.486305
# min                       0.000000                             0.000000
# 25%                       0.000000                             0.000000
# 50%                       0.000000                             0.000000
# 75%                       0.000000                             0.000000
# max                    1338.150000                          5500.600000
#
#        surface_planchers_bas_deperditifs  \
# count                       69850.000000
# mean                           12.700769
# std                            72.907478
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             0.000000
# max                          5500.600000
#
#        surface_parois_verticales_opaques_deperditives  etat_avancement  \
# count                                    69850.000000          89445.0
# mean                                        17.028372              1.0
# std                                        243.190786              0.0
# min                                       -140.330000              1.0
# 25%                                          0.000000              1.0
# 50%                                          0.000000              1.0
# 75%                                          0.000000              1.0
# max                                      51090.000000              1.0
#
#          dpe_vierge  est_efface
# count  84462.000000     89445.0
# mean       0.349435         0.0
# std        0.476794         0.0
# min        0.000000         0.0
# 25%        0.000000         0.0
# 50%        0.000000         0.0
# 75%        1.000000         0.0
# max        1.000000         0.0
#
# [8 rows x 36 columns]

# %% [markdown]
# ## Baseline model

# %% [markdown]
# We preprocess the data as follows :
#
# We convert the scores to numeric values using a dictionnary, and we define the score column as the target.
#
# Then we drop some irrelevent columns concerning our problem.
#
# Last but not least, we split the data into the test set and train set.

# %%
# Correspondance entre catégoriel et int8
int_to_cat = {
    0: "A",
    1: "B",
    2: "C",
    3: "D",
    4: "E",
    5: "F",
    6: "G",
}
# Mapping categories to int
cat_to_int = {v: k for k, v in int_to_cat.items()}

target_column_name = 'classe_consommation_energie'

ignore_column_names = ['id', 'numero_dpe', 'version_methode_dpe',
                        'nom_methode_etude_thermique', 'version_methode_etude_thermique',
                        'commentaires_ameliorations_recommandations',
                        'explication_personnalisee', 'estimation_ges',
                        'classe_estimation_ges', 'nom_rue', 'numero_rue',
                        'batiment', 'escalier', 'etage', 'porte', 'numero_lot',
                        'partie_batiment', 'adresse_organisme_certificateur'
                        ]
dataSets = list()
for data in [train, test]:
    X_df = data.drop([target_column_name] + ignore_column_names, axis=1)
    # y_array = y_array.map(cat_to_int).fillna(-1).astype("int8").values
    y = np.array(data[target_column_name].map(cat_to_int).fillna(-1).astype("int8"))
    X = X_df
    dataSets.append(X)
    dataSets.append(y)
train_X, train_y, test_X, test_y = dataSets[0], dataSets[1], dataSets[2], dataSets[3]

# %%
print(train_X.shape, test_X.shape, test_X.shape, test_y.shape)
print(len(train_X.columns), len(test_X.columns))
# Out:
# (62611, 48) (26834, 48) (26834, 48) (26834,)
# 48 48

# %% [markdown]
# As ```rampwf``` can only read X and y as ```np.arrays```, we extract the column's indexes to use them in our classifier.

# %%
liste1 = list()
for i in ['code_postal', 'code_insee_commune']:
    liste1.append(list(train_X.columns).index(i))
print(liste1)

liste2 = list()
for i in ['portee_dpe_batiment', 'shon', 'surface_utile',
                                            'surface_thermique_parties_communes', 'en_souterrain', 'en_surface',
                                            'nombre_niveaux', 'nombre_circulations_verticales',
                                            'type_vitrage_verriere', 'surface_baies_orientees_nord',
                                            'surface_baies_orientees_est_ouest', 'surface_baies_orientees_sud',
                                            'surface_planchers_hauts_deperditifs',
                                            'surface_planchers_bas_deperditifs',
                                            'surface_parois_verticales_opaques_deperditives', 'etat_avancement',
                                            'dpe_vierge', 'est_efface']:
    liste2.append(list(train_X.columns).index(i))
print(liste2)
# Out:
# [19, 20]
# [23, 24, 25, 26, 27, 28, 29, 30, 34, 37, 38, 39, 40, 41, 42, 43, 45, 46]

# %%
# %%writefile submissions/starting_kit/classifier.py
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.base import BaseEstimator, TransformerMixin


class UniformingdType(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        X = X.astype(object)
        return X


class toStr(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        X = X.astype(str)
        return X


class Classifier(BaseEstimator):
    def __init__(self):
        # Definir les imputers et les scalers.
        qual_imputer = SimpleImputer(strategy="most_frequent")
        quant_imputer = SimpleImputer(strategy="mean")
        scaler = StandardScaler()

        # Transformations.
        qual_transform = Pipeline(steps=[
            ("previus", UniformingdType()),
            ("imputer", qual_imputer),
            ("toStr", toStr()),
            ("encoder", OneHotEncoder(handle_unknown='ignore'))
        ])

        quant_transform = Pipeline(steps=[
            ("imputer", quant_imputer),
            ("scaler", scaler)
        ])

        # ColumnTransformer para apliquer des transformations
        # differentes a les columnes.
        self.transformer = ColumnTransformer(
            transformers=[
                ("qual", qual_transform, [19, 20]),
                ("quant", quant_transform, [23, 24, 25, 26, 27,
                                            28, 29, 30, 34, 37, 38,
                                            39, 40, 41, 42, 43, 45, 46]),
            ],
            remainder='drop'
        )

        # Definir le model de clasification.
        self.model = LogisticRegression(max_iter=1000, random_state=42)

        # Construction du pipeline complet.
        self.pipe = make_pipeline(self.transformer, self.model)

    def fit(self, X, y):
        self.pipe.fit(X, y)

    def predict(self, X):
        return self.pipe.predict(X)

    def predict_proba(self, X):
        return self.pipe.predict_proba(X)

# %%
classifier = Classifier()
classifier.pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('qual',
#                                                   Pipeline(steps=[('previus',
#                                                                    UniformingdType()),
#                                                                   ('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('toStr',
#                                                                    toStr()),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   [19, 20]),
#                                                  ('quant',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   [23, 24, 25, 26, 27, 28, 29,
#                                                    30, 34, 37, 38, 39, 40, 41,
#                                                    42, 43, 45, 46])])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, random_state=42))])

# %%
# !ramp-test --submission starting_kit
# Out:
# Testing Energetic class prediction for housing in Paris
# Reading train and test files from ./data/ ...
# ./problem.py:55: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(os.path.join(path, 'data', f_name))
# ./problem.py:55: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(os.path.join(path, 'data', f_name))
# ./problem.py:55: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(os.path.join(path, 'data', f_name))
# Reading cv ...
# Training submissions/starting_kit ...
# CV fold 0
# /home/julian/miniconda3/envs/DPE/lib/python3.9/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [8]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/julian/miniconda3/envs/DPE/lib/python3.9/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [8]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/julian/miniconda3/envs/DPE/lib/python3.9/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [8]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# 	score  balanced acc    acc       time
# 	train          0.25  0.544  25.379761
# 	valid          0.23  0.534   0.635267
# 	test           0.23  0.534   0.276026
# CV fold 1
# /home/julian/miniconda3/envs/DPE/lib/python3.9/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [8]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/julian/miniconda3/envs/DPE/lib/python3.9/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [8]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/julian/miniconda3/envs/DPE/lib/python3.9/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [8]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# 	score  balanced acc    acc       time
# 	train          0.25  0.547  23.831870
# 	valid          0.23  0.530   0.611863
# 	test           0.23  0.532   0.343067
# CV fold 2
# /home/julian/miniconda3/envs/DPE/lib/python3.9/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [8]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/julian/miniconda3/envs/DPE/lib/python3.9/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [8]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /home/julian/miniconda3/envs/DPE/lib/python3.9/site-packages/sklearn/impute/_base.py:577: UserWarning: Skipping features without any observed values: [8]. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# 	score  balanced acc    acc       time
# 	train          0.25  0.544  27.853168
# 	valid          0.23  0.535   0.611285
# 	test           0.23  0.532   0.263402
# ----------------------------
# Mean CV scores
# ----------------------------
# 	score  balanced acc             acc         time
# 	train  0.25 ± 0.003  0.545 ± 0.0012  25.7 ± 1.66
# 	valid  0.23 ± 0.001  0.533 ± 0.0023   0.6 ± 0.01
# 	test   0.23 ± 0.001  0.533 ± 0.0006   0.3 ± 0.03
# ----------------------------
# Bagged scores
# ----------------------------
# 	score  balanced acc    acc
# 	valid          0.23  0.534
# 	test           0.23  0.532
